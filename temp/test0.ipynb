# %%
d = {
    'd8c79b144669477493bf063d2af51ed3': {'category': 5, 'id': 'd8c79b144669477493bf063d2af51ed3', 'x': 1.114,
                                         'y': 538.952, 'width': 71.451, 'height': 27.385,
                                         'value': 'S1\nV1\nT2\nE-6025\nD1\nS2\nT1'},
    '949f1584a5d449aeb9d009147a919646': {'category': 12, 'id': '949f1584a5d449aeb9d009147a919646', 'x': 54.833,
                                         'y': 518.461, 'width': 56.356, 'height': 450.252,
                                         'value': 'N12\n3\n5F\nN1\n4\nN7\nK34A\nK32A\nK34C\n25E\nK34B\nK32B\n△HN8\nK34D\nN4'}
}

# d2 = sorted(d, key=lambda obj: print(obj))
sorted_items = sorted(d.items(), key=lambda item: item[1]['x'])
print(sorted_items)
# Out:
# [('d8c79b144669477493bf063d2af51ed3', {'category': 5, 'id': 'd8c79b144669477493bf063d2af51ed3', 'x': 1.114, 'y': 538.952, 'width': 71.451, 'height': 27.385, 'value': 'S1\nV1\nT2\nE-6025\nD1\nS2\nT1'}), ('949f1584a5d449aeb9d009147a919646', {'category': 12, 'id': '949f1584a5d449aeb9d009147a919646', 'x': 54.833, 'y': 518.461, 'width': 56.356, 'height': 450.252, 'value': 'N12\n3\n5F\nN1\n4\nN7\nK34A\nK32A\nK34C\n25E\nK34B\nK32B\n△HN8\nK34D\nN4'})]

# %%
from itertools import groupby

data = [
    [0.0, 0.15566, 0.327509, 0.012457, 0.014824],
    [0.0, 0.172455, 0.319573, 0.014484, 0.021101],
    [7.0, 0.070443, 0.390652, 0.067004, 0.017282],
    [7.0, 0.070766, 0.423895, 0.067166, 0.017041],
    [6.0, 0.080179, 0.509243, 0.065293, 0.017855],
    [0.0, 0.146202, 0.308519, 0.011954, 0.014874],
    [12.0, 0.303676, 0.432269, 0.036817, 0.386976],
]

sorted_data = sorted(data, key=lambda item: item[0])

# 使用 groupby 函数进行分组
grouped_data = {key: list(group) for key, group in groupby(sorted_data, key=lambda x: x[0])}
print(grouped_data)

sorted_grouped_data = {key: sorted(group, key=lambda x: x[1]) for key, group in grouped_data.items()}
print(sorted_grouped_data)

# 对 data 的数据项的第一个数据进行分组
# grouped_data = group_by(data, lambda item: item[0])

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个简单的图
G = nx.Graph()

# G.add_edge('A', 'B')
# G.add_edge('B', 'C')
# G.add_edge('C', 'D')
# G.add_edge('D', 'A')

edges = [
    ('A', 'B'),
    ('B', 'C'),
    ('C', 'D'),
    ('D', 'A')
]
# 手动指定节点的位置
pos = {
    'A': (1, 0),
    'B': (1, 1),
    'C': (2, 0),
    'D': (1, -1)
}

# for node, data in nodes.items():
#     G.add_node(node, pos=data['pos'], size=data['size'], type=data['type'])


for edge in edges:
    nx.draw_networkx_edges(G, pos, edgelist=[edge], connectionstyle='Angle', arrows=True)

# 绘制图并使用自定义布局
nx.draw(G, pos=pos, with_labels=True, node_color='lightblue', node_size=1500, font_weight='bold', font_size=12,
        arrowsize=20)

# plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.random_geometric_graph(10, 0.3)

# pos = nx.spring_layout(G)  # 使用 spring 布局算法
pos = nx.kamada_kawai_layout(G)
# pos = nx.fruchterman_reingold_layout(G)
edges = G.edges()

nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos, edgelist=edges)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个简单的图
G = nx.MultiDiGraph()
G.add_edge('A', 'B')
G.add_edge('B', 'C')
G.add_edge('C', 'D')
G.add_edge('D', 'A')

# 手动指定节点的位置
custom_pos = {
    'A': (0, 0),
    'B': (1, 1),
    'C': (2, 0),
    'D': (1, -1)
}

# 绘制图并使用自定义布局
# edges = nx.draw_networkx_edges(G, pos=custom_pos, arrows=True, connectionstyle='Angle')
# edges = nx.draw_networkx_edges(G, pos=custom_pos, arrows=True, connectionstyle='Arc')
# edges = nx.draw_networkx_edges(G, pos=custom_pos, arrows=True, connectionstyle='Bar')
# edges = nx.draw_networkx_edges(G, pos=custom_pos, connectionstyle='Angle')

edges = nx.draw_networkx_edges(G, pos=custom_pos, arrows=True, connectionstyle='Angle')
# edges = nx.draw_networkx_edges(G, pos=custom_pos, arrows=True, connectionstyle='Angle', style='--', arrowstyle='-|>')
# print(edges[0].set_connectionstyle('Angle,angleA=0,angleB=90,rad=10'))


# nx.draw(G, pos=custom_pos, with_labels=True, node_color='lightblue', node_size=1500, font_weight='bold', font_size=12,
#         arrowsize=20)
nx.draw(G, pos=custom_pos, with_labels=True, node_color='lightblue', node_size=1500, font_weight='bold', font_size=12)

plt.show()

# %%
import itertools
import matplotlib.pyplot as plt
import networkx as nx

subset_sizes = [5, 5, 4, 3, 2, 4, 4, 3]
subset_color = [
    "gold",
    "violet",
    "violet",
    "violet",
    "violet",
    "limegreen",
    "limegreen",
    "darkorange",
]


def multilayered_graph(*subset_sizes):
    extents = nx.utils.pairwise(itertools.accumulate((0,) + subset_sizes))
    layers = [range(start, end) for start, end in extents]
    G = nx.Graph()
    for (i, layer) in enumerate(layers):
        G.add_nodes_from(layer, layer=i)
    for layer1, layer2 in nx.utils.pairwise(layers):
        G.add_edges_from(itertools.product(layer1, layer2))
    return G


G = multilayered_graph(*subset_sizes)
color = [subset_color[data["layer"]] for v, data in G.nodes(data=True)]
pos = nx.multipartite_layout(G, subset_key="layer")
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_color=color, with_labels=False)
plt.axis("equal")
plt.show()

# %%
import networkx as nx

import matplotlib.pyplot as plt

H = nx.DiGraph()

data = [
    {'category': 7, 'id': '3480d6f2822d44c695d2e7a1bc20818f', 'x': 194.66500000000002, 'y': 389.729, 'width': 100.506,
     'height': 16.401, 'value': '去T-6010\n6001k\n开车气相丙烯'
     },
    {'category': 7, 'id': '2b9bbc99968f48258cb9a59179d6b2a4', 'x': 179.149, 'y': 418.276, 'width': 100.749,
     'height': 16.172, 'value': '去11-V-6005\n6036\n开车气相丙烯'
     },
    {'category': 7, 'id': '07741f6324ba446492ba353251341de7', 'x': 408.648, 'y': 885.548, 'width': 42.897,
     'height': 10.616, 'value': 'CBD\n9002'
     },
    {'category': 7, 'id': '25cf718a35a24667b2b3c070f516b879', 'x': 1093.661, 'y': 758.205, 'width': 43.902,
     'height': 10.694, 'value': '9002\nCBD'
     },
    {'category': 7, 'id': '853602ec86004ff4ab40c899391da89e', 'x': 1129.471, 'y': 134.801, 'width': 44.679,
     'height': 10.898, 'value': '9003\nHFL'
     },
    {'category': 7, 'id': 'dd46eb374cf547c09b41579a75c53d5c', 'x': 1134.322, 'y': 582.989, 'width': 44.255,
     'height': 10.661, 'value': '9002\nCBD'
     },
    {'category': 7, 'id': 'fe1ca2f6c2ce49378068f1beb4ad1b09', 'x': 1152.226, 'y': 411.368, 'width': 45.389,
     'height': 10.533, 'value': '9007\nCWR'
     },
    {'category': 7, 'id': 'dab680b873104f4fb62dbdbcb07b416e', 'x': 1485.129, 'y': 188.586, 'width': 102.981,
     'height': 16.264, 'value': '去11-R-6010A/S\n6004\n开车气相丙烯'
     },
    {'category': 7, 'id': '09dfbdb58de244c1873ea36df9eb5a43', 'x': 1305.179, 'y': 221.352, 'width': 101.76,
     'height': 17.051, 'value': '2#丙烯塔顶\n6010\n去E-6022'
     },
    {'category': 7, 'id': '99330fba57cf41359d21610f6f329a0a', 'x': 1301.844, 'y': 319.056, 'width': 100.452,
     'height': 17.586, 'value': '混合碳三\n6001\n去P-30046'
     },
    {'category': 7, 'id': 'be8130e03fe549f4bb74e2d0a8157641', 'x': 1308.773, 'y': 734.734, 'width': 101.043,
     'height': 17.992, 'value': 'C3\n6007\n去T-6020'
     },
    {'category': 7, 'id': '9d97bb59da2042e99aa276063673ffd2', 'x': 1311.947, 'y': 686.23, 'width': 101.496,
     'height': 17.553, 'value': 'C3\n6010\n去11-V-6020'
     },
    {'category': 7, 'id': '6fae17b9fca54c3ea546f6accb12dbea', 'x': 1308.207, 'y': 709.203, 'width': 100.932,
     'height': 16.922, 'value': 'C3\n6036\n去11-V-6005'
     },
    {'category': 7, 'id': 'c01044c80189449fba3d066f15355adb', 'x': 1302.291, 'y': 623.494, 'width': 99.184,
     'height': 16.088, 'value': 'C3\n6002\n去P-6010A/S'
     },
    {'category': 7, 'id': '433e9760c1b64d20b40f76712e266e34', 'x': 1308.291, 'y': 656.691, 'width': 101.081,
     'height': 17.38, 'value': 'C3\n6007\n去11-E-6021'
     },
    {'category': 7, 'id': '461d3a121d144c6aa2861311ad2b1244', 'x': 1297.736, 'y': 599.438, 'width': 99.003,
     'height': 16.862, 'value': 'C3\n6005\n去11-V-6015'
     },
    {'category': 7, 'id': '29355c927ab944dda5a76e5f1762b10c', 'x': 1439.236, 'y': 716.266, 'width': 43.668,
     'height': 10.468, 'value': '9007\nCWR'
     },
    {'category': 7, 'id': '2d67d4ec3e1d49f5a168996ab7bebe55', 'x': 1437.322, 'y': 604.255, 'width': 43.134,
     'height': 10.019, 'value': '9003\nHF'
     },
    {'category': 6, 'id': '7848346b94324b15a13a794c7f1dbf49', 'x': 270.269, 'y': 499.272, 'width': 97.94,
     'height': 16.944, 'value': '碳三馏分\n6007\n来自T-6020'
     },
    {'category': 6, 'id': '6a1792fe1e1d403b8db960e3f45ebb8a', 'x': 1159.048, 'y': 257.724, 'width': 44.788,
     'height': 10.983, 'value': 'LN\n9010'
     },
    {'category': 6, 'id': 'bf351e35632d4a3f8fdfe77a62f82334', 'x': 1163.164, 'y': 472.347, 'width': 43.408,
     'height': 10.471, 'value': 'CWS\n9007'
     },
    {'category': 6, 'id': '94976eb8cf31416b928c3a5678094250', 'x': 1205.056, 'y': 280.535, 'width': 101.231,
     'height': 17.493, 'value': '碳三回流\n6010\n来自P-6020A/S'
     },
    {'category': 6, 'id': '7b89ef3b3d3545a2954e4d24f0a4e2f1', 'x': 1123.457, 'y': 505.958, 'width': 99.71,
     'height': 16.379, 'value': 'N\n丙烯回收\n6031\n来自P-6002'
     },
    {'category': 6, 'id': '76fbd18172014a3cad36ae7ddbefdcfe', 'x': 1473.505, 'y': 702.393, 'width': 42.876,
     'height': 10.321, 'value': 'WS\n9007'
     },
    {'category': 12, 'id': 'a943ccd725564c558815fb2d79787a40', 'x': 455.514, 'y': 410.223, 'width': 55.226,
     'height': 367.24, 'value': 'tower 6021'
     }
]

# # data 中，按照 category 进行分组
# grouped_data = {key: list(group) for key, group in groupby(data, key=lambda x: x['category'])}
# 
# # 对 grouped_data 中，category=6 的所有数据项，x 设置为 0 ， y 进行排序
# for item in grouped_data[6]:
#     item['x'] = 0
# grouped_data[6] = sorted(grouped_data[6], key=lambda x: x['y'])
# print(grouped_data[6])

delta_y = 20
current_input_y = 0
# 以 index 和 value 的方式遍历 data，同时将数据更新回 data
for index, item in enumerate(data):
    # 如果 category 为 6
    if item['category'] == 6:
        # 设置 x 为 0
        item['x'] = 0
        # 设置 y 为 index * delta_y
        item['y'] = current_input_y = index * delta_y
        data[index] = item

for index, item in enumerate(data):
    # 如果 category 为 6
    if item['category'] == 7:
        # 设置 x 为 0
        item['x'] = 800
        # 设置 y 为 index * delta_y
        item['y'] = current_input_y - index * delta_y
        data[index] = item
        # print(data[index])

node_list = []
pos_list = {}
# 遍历 data，构造成图的节点
for item in data:
    H.add_node(item['value'])
    pos_list[item['value']] = (item['x'], item['y'])
    # print((item['x'], item['y']))

# print(pos_list)

link = [
    {
        "input": {
            "category": 6,
            "textKey": "碳三馏分"
        },
        "output": {
            "category": 12,
            "textKey": "6021"
        }
    },
    {
        "output": {
            "category": 7,
            "textKey": "6005"
        },
        "input": {
            "category": 12,
            "textKey": "6021"
        }
    },
    {
        "output": {
            "category": 7,
            "textKey": "6010"
        },
        "input": {
            "category": 12,
            "textKey": "6021"
        }
    },
    {
        "output": {
            "category": 7,
            "textKey": "6022"
        },
        "input": {
            "category": 12,
            "textKey": "6021"
        }
    }
]

edges = []
# 遍历 link
for item in link:
    # 获取 input 和 output 的值
    input_category = item['input']['category']
    input_value = item['input']['textKey']
    output_category = item['output']['category']
    output_value = item['output']['textKey']

    # 从 data 中找到 category 与 input_category , value 包含 input_value 相同的数据项
    input_data = [x for x in data if x['category'] == input_category and input_value in x['value']]

    # 从 data 中找到 category 与 output_category , value 包含 output_value 相同的数据项
    output_data = [x for x in data if x['category'] == output_category and output_value in x['value']]

    # 如果 input_data 和 output_data 都不为空
    if input_data and output_data:
        # 添加边
        H.add_edge(input_data[0]["value"], output_data[0]["value"])

plt.figure(figsize=(20, 20))

#Plotting Graph
# nx.draw(H, with_labels=True, node_color=colors, node_size=sizes, pos=pos)
nx.draw(H, with_labels=True, pos=pos_list)
nx.draw_networkx_edges(G, pos=pos_list, connection='arc3', edge_color='black', width=2)
# 保存图为图片
# plt.savefig("graph_image.png")

# %%
import networkx as nx
import matplotlib.pyplot as plt

H = nx.DiGraph()

#adding nodes
H.add_nodes_from([
    ("blue", {"color": "blue", "size": 1000, "pos": (0, 0)}),
    ("yellow", {"color": "yellow", "size": 1000, "pos": (0, 2)}),
    ("orange", {"color": "orange", "size": 1000, "pos": (4, 3)}),
    ("red", {"color": "red", "size": 1000, "pos": (4, 5)}),
    ("tower", {"color": "green", "size": 1000, "pos": (0, 5)})
])
#adding edges
H.add_edges_from([
    ("blue", "yellow"),
    ("yellow", "orange"),
    ("yellow", "red"),
    ("orange", "red"),
    ("red", "tower")
])
# node_colors = nx.get_node_attributes(H, "color").values()
# colors = list(node_colors)
node_sizes = nx.get_node_attributes(H, "size").values()
sizes = list(node_sizes)

node_pos = nx.get_node_attributes(H, "pos").values()
node_key = nx.nodes(H)

pos = dict(zip(node_key, node_pos))

#Plotting Graph
nx.draw(H, with_labels=True, pos=pos)
# nx.draw(H, with_labels=True, node_color=colors, node_size=sizes, pos=pos)

# 保存图为图片
# plt.savefig("graph_image.png")
